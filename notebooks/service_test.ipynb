# %%
import requests
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/cirrhosis.csv")
df.head()
# Out:
#    id  N_Days             Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0   0     999  D-penicillamine  21532   M       N            N       N     N
# 1   1    2574          Placebo  19237   F       N            N       N     N
# 2   2    3428          Placebo  13727   F       N            Y       Y     Y
# 3   3    2576          Placebo  18460   F       N            N       N     N
# 4   4     788          Placebo  16658   F       N            Y       N     N
#
#    Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0        2.3        316.0     3.35   172.0    1601.0  179.80           63.0
# 1        0.9        364.0     3.54    63.0    1440.0  134.85           88.0
# 2        3.3        299.0     3.55   131.0    1029.0  119.35           50.0
# 3        0.6        256.0     3.50    58.0    1653.0   71.30           96.0
# 4        1.1        346.0     3.65    63.0    1181.0  125.55           96.0
#
#    Platelets  Prothrombin  Stage Status
# 0      394.0          9.7    3.0      D
# 1      361.0         11.0    3.0      C
# 2      199.0         11.7    4.0      D
# 3      269.0         10.7    3.0      C
# 4      298.0         10.6    4.0      C

# %%
json_data = df.to_json(orient='records')
json_data
# Out:
# '[{"id":0,"N_Days":999,"Drug":"D-penicillamine","Age":21532,"Sex":"M","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":2.3,"Cholesterol":316.0,"Albumin":3.35,"Copper":172.0,"Alk_Phos":1601.0,"SGOT":179.8,"Tryglicerides":63.0,"Platelets":394.0,"Prothrombin":9.7,"Stage":3.0,"Status":"D"},{"id":1,"N_Days":2574,"Drug":"Placebo","Age":19237,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.9,"Cholesterol":364.0,"Albumin":3.54,"Copper":63.0,"Alk_Phos":1440.0,"SGOT":134.85,"Tryglicerides":88.0,"Platelets":361.0,"Prothrombin":11.0,"Stage":3.0,"Status":"C"},{"id":2,"N_Days":3428,"Drug":"Placebo","Age":13727,"Sex":"F","Ascites":"N","Hepatomegaly":"Y","Spiders":"Y","Edema":"Y","Bilirubin":3.3,"Cholesterol":299.0,"Albumin":3.55,"Copper":131.0,"Alk_Phos":1029.0,"SGOT":119.35,"Tryglicerides":50.0,"Platelets":199.0,"Prothrombin":11.7,"Stage":4.0,"Status":"D"},{"id":3,"N_Days":2576,"Drug":"Placebo","Age":18460,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.6,"Cholesterol":256.0,"Albumin":3.5,"Copper":58.0,"Alk_Phos":1653.0,"SGOT":71.3,"Tryglicerides":96.0,"Platelets":269.0,"Prothrombin":10.7,"Stage":3.0,"Status":"C"},{"id":4,"N_Days":788,"Drug":"Placebo","Age":16658,"Sex":"F","Ascites":"N","Hepatomegaly":"Y","Spiders":"N","Edema":"N","Bilirubin":1.1,"Cholesterol":346.0,"Albumin":3.65,"Copper":63.0,"Alk_Phos":1181.0,"SGOT":125.55,"Tryglicerides":96.0,"Platelets":298.0,"Prothrombin":10.6,"Stage":4.0,"Status":"C"},{"id":5,"N_Days":703,"Drug":"D-penicillamine","Age":19270,"Sex":"F","Ascites":"N","Hepatomegaly":"Y","Spiders":"N","Edema":"N","Bilirubin":0.6,"Cholesterol":227.0,"Albumin":3.46,"Copper":34.0,"Alk_Phos":6456.2,"SGOT":60.63,"Tryglicerides":68.0,"Platelets":213.0,"Prothrombin":11.5,"Stage":3.0,"Status":"D"},{"id":6,"N_Days":1300,"Drug":"Placebo","Age":17703,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":1.0,"Cholesterol":328.0,"Albumin":3.35,"Copper":43.0,"Alk_Phos":1677.0,"SGOT":137.95,"Tryglicerides":90.0,"Platelets":291.0,"Prothrombin":9.8,"Stage":3.0,"Status":"C"},{"id":7,"N_Days":1615,"Drug":"Placebo","Age":21281,"Sex":"F","Ascites":"N","Hepatomegaly":"Y","Spiders":"N","Edema":"N","Bilirubin":0.6,"Cholesterol":273.0,"Albumin":3.94,"Copper":36.0,"Alk_Phos":598.0,"SGOT":52.7,"Tryglicerides":214.0,"Platelets":227.0,"Prothrombin":9.9,"Stage":3.0,"Status":"C"},{"id":8,"N_Days":2050,"Drug":"D-penicillamine","Age":20684,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.7,"Cholesterol":360.0,"Albumin":3.65,"Copper":72.0,"Alk_Phos":3196.0,"SGOT":94.55,"Tryglicerides":154.0,"Platelets":269.0,"Prothrombin":9.8,"Stage":2.0,"Status":"C"},{"id":9,"N_Days":2615,"Drug":"D-penicillamine","Age":15009,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.9,"Cholesterol":478.0,"Albumin":3.6,"Copper":39.0,"Alk_Phos":1758.0,"SGOT":171.0,"Tryglicerides":140.0,"Platelets":234.0,"Prothrombin":10.6,"Stage":2.0,"Status":"C"},{"id":10,"N_Days":3581,"Drug":"Placebo","Age":25772,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.5,"Cholesterol":252.0,"Albumin":3.6,"Copper":26.0,"Alk_Phos":377.0,"SGOT":56.76,"Tryglicerides":185.0,"Platelets":336.0,"Prothrombin":10.0,"Stage":2.0,"Status":"C"},{"id":11,"N_Days":1614,"Drug":"Placebo","Age":14106,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.9,"Cholesterol":328.0,"Albumin":3.61,"Copper":62.0,"Alk_Phos":1105.0,"SGOT":137.95,"Tryglicerides":95.0,"Platelets":145.0,"Prothrombin":9.5,"Stage":3.0,"Status":"C"},{"id":12,"N_Days":1847,"Drug":"Placebo","Age":12279,"Sex":"F","Ascites":"N","Hepatomegaly":"N","Spiders":"N","Edema":"N","Bilirubin":0.6,"Cholesterol":232.0,"Albumin":3.68,"Copper":38.0,"Alk_Phos":1029.0,"SGOT":128.65,"Tryglicerides":99.0,"Platelets":273.0,"Prothrombin":10.7,"Stage":2.0,"Status":"C"},{"id":13,"N_Days":1153,"Drug":"D-penicillamine","Age":22347,"Sex": ...

# %%
response = requests.post(
    "http://0.0.0.0:3000/predict", 
    data=json_data
    
)

predictions = response.json()

# %%
df_predictions = pd.DataFrame.from_dict(predictions, orient='columns')
df_predictions.head()
# Out:
#    id  Status_C  Status_CL  Status_D
# 0   0  0.015916   0.000227  0.983858
# 1   1  0.893313   0.000641  0.106046
# 2   2  0.000384   0.000667  0.998949
# 3   3  0.984367   0.000121  0.015512
# 4   4  0.925573   0.038547  0.035879
